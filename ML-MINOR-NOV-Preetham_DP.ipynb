# %% [markdown]
# # ML-MINOR-NOV

# %%
# Import required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load your data and print out a few lines. Perform operations to inspect data
# types and look for instances of missing or possibly errant data.
# Read the CSV File Using Pandas read_csv function
df = pd.read_csv('tmdb-movies.csv')

# %%
df
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %% [markdown]
# The movies dataset has:
# 1.Rows = 10866
# 2.Columns = 21

# %%
# print the concise summery of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %% [markdown]
# The movies dataset has:
# 1.Rows = 10866
# 2.Columns = 21

# %%
#print first two rows of the dataset
df.head(2)
# Out:
#        id    imdb_id  popularity     budget     revenue      original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810      Jurassic World
# 1   76341  tt1392190   28.419936  150000000   378436354  Mad Max: Fury Road
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
#
#                         homepage         director             tagline  ...  \
# 0  http://www.jurassicworld.com/  Colin Trevorrow   The park is open.  ...
# 1    http://www.madmaxmovie.com/    George Miller  What a Lovely Day.  ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
#
# ...

# %%
#print Last two rows of the dataset
df.tail(2)
# Out:
#           id    imdb_id  popularity  budget  revenue  \
# 10864  21449  tt0061177    0.064317       0        0
# 10865  22293  tt0060666    0.035919   19000        0
#
#                  original_title  \
# 10864    What's Up, Tiger Lily?
# 10865  Manos: The Hands of Fate
#
#                                                     cast homepage  \
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...      NaN
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...      NaN
#
#                director                                       tagline  ...  \
# 10864       Woody Allen                     WOODY ALLEN STRIKES BACK!  ...
# 10865  Harold P. Warren  It's Shocking! It's Beyond Your Imagination!  ...
#
#                                                 overview runtime  \
# 10864  In comic Woody Allen's film debut, he took the...      80
# 10865  A family gets lost on the road and stumbles up...      74
#
# ...

# %%
#print concise summery of the dataset
df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %%
#since the dataset contain null values also 
#count total rows in each column which contain null values
df.isna().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
#fill the null values with zero using 'fillna' function
#I don't want to update it with zero because some rows also contain string values.
df.fillna(0)
print()

# %% [markdown]
# # Data cleaning
# 1.Remove Duplicate Rows
# 2.Changing Format Of Release Date Into Datetime Format
# 3.Remove the unused colums that are not needes in the analysis process
# 4.Drop theses rows which contain incorrect or inappropriate values.

# %% [markdown]
# 1.Remove Duplicate Rows

# %%
#'duplicated()' function in pandas return the duplicate row as True and othter as False
#for counting the duplicate elements we sum all the rows
sum(df.duplicated())
# Out:
# 1

# %%
#After calculating the duplicate row we can drop these row using 'drop_duplicates()' function
df.drop_duplicates(inplace = True)
#afetr removing duplicate value from the dataset
print("Afetr Removing Duplicate Values (Rows,Columns) : ",df.shape)
# Out:
# Afetr Removing Duplicate Values (Rows,Columns) :  (10865, 21)

# %% [markdown]
# 2.Changing Format Of Release Date Into Datetime Format

# %%
#the the given in the dataset is in string format.
#So we need to change this in datetime format

df['release_date'] = pd.to_datetime(df['release_date'])
df['release_date'].head()
# Out:
# 0   2015-06-09
# 1   2015-05-13
# 2   2015-03-18
# 3   2015-12-15
# 4   2015-04-01
# Name: release_date, dtype: datetime64[ns]

# %% [markdown]
# 3.Remove the unused colums that are not needes in the analysis process

# %%
# After discussing the structure of the data and any problems that need to be
#   cleaned, perform those cleaning steps in the second part of this section
#we can see that 21 columns in the dataset, We can drop them using drop function.
df.drop(['budget_adj','revenue_adj','overview','imdb_id','homepage','tagline'],axis =1,inplace = True)
print("Afetr Removing Unused Columns (Rows,Columns) : ",df.shape)
# Out:
# Afetr Removing Unused Columns (Rows,Columns) :  (10865, 15)

# %% [markdown]
# 4. Drop theses rows which contain incorrect or inappropriate values.

# %%
# Checking for an zero values in the budget and revenue columns
print("Rows With Zero Values In The Budget Column:",df[(df['budget']==0)].shape[0])
print("Rows With Zero Values In The Revenue Column:",df[(df['revenue']==0)].shape[0])
# Out:
# Rows With Zero Values In The Budget Column: 5696
# Rows With Zero Values In The Revenue Column: 6016

# %%
# make group for each year and count the number of movies in each year 
data=df.groupby('release_year').count()['id']
print(data)
# Out:
# release_year
# 1960     32
# 1961     31
# 1962     32
# 1963     34
# 1964     42
# 1965     35
# 1966     46
# 1967     40
# 1968     39
# 1969     31
# 1970     41
# 1971     55
# 1972     40
# 1973     55
# 1974     47
# 1975     44
# 1976     47
# 1977     57
# 1978     65
# 1979     57
# 1980     78
# 1981     82
# 1982     81
# 1983     80
# 1984    105
# 1985    109
# 1986    121
# 1987    125
# 1988    145
# 1989    137
# 1990    132
# 1991    133
# 1992    133
# 1993    178
# 1994    184
# 1995    175
# 1996    204
# 1997    192
# 1998    210
# 1999    224
# 2000    227
# 2001    242
# 2002    266
# 2003    281
# 2004    307
# 2005    364
# 2006    408
# 2007    438
# 2008    496
# 2009    533
# 2010    489
# 2011    540
# 2012    588
# 2013    659
# 2014    700
# 2015    629
# Name: id, dtype: int64

# %%
#Sorting of values Budget and Revenue
df = df.sort_values(["budget","revenue"])

# %%
df
# Out:
#           id  popularity     budget     revenue  \
# 74    347096    2.165433          0           0
# 75    308369    2.141506          0           0
# 92    370687    1.876037          0           0
# 100   326359    1.724712          0           0
# 101   254302    1.661789          0           0
# ...      ...         ...        ...         ...
# 6570    1452    1.957331  270000000   391081192
# 14     99861    5.944927  280000000  1405035767
# 7387     285    4.965391  300000000   961000000
# 3375    1865    4.955130  380000000  1021683000
# 2244   46528    0.250540  425000000    11087569
#
#                                    original_title  \
# 74                         Mythica: The Darkspore
# 75                 Me and Earl and the Dying Girl
# 92                       Mythica: The Necromancer
# 100                                  Frozen Fever
# 101                                     High-Rise
# ...                                           ...
# ...

# %%
#ECDF function to plot ECDF.
def ecdf(data):
    x = np.sort(data)
    y = np.arange(1,len(data)+1)/len(data)
    return x,y

# %% [markdown]
# # 1.Which are the movies with the third-lowest and third-highest budget?

# %%
#Feature selection.
q1 = df[['budget','original_title']]

# %%
q1
# Out:
#          budget                               original_title
# 74            0                       Mythica: The Darkspore
# 75            0               Me and Earl and the Dying Girl
# 92            0                     Mythica: The Necromancer
# 100           0                                 Frozen Fever
# 101           0                                    High-Rise
# ...         ...                                          ...
# 6570  270000000                             Superman Returns
# 14    280000000                      Avengers: Age of Ultron
# 7387  300000000     Pirates of the Caribbean: At World's End
# 3375  380000000  Pirates of the Caribbean: On Stranger Tides
# 2244  425000000                            The Warrior's Way
#
# [10865 rows x 2 columns]

# %%
sortedList1 = q1.sort_values("budget")

# %%
sortedList1
# Out:
#          budget                               original_title
# 74            0                       Mythica: The Darkspore
# 8842          0                       The Filth and the Fury
# 8840          0                                     The Dish
# 8839          0          Dave Chappelle: Killin' Them Softly
# 8838          0                            The Man Who Cried
# ...         ...                                          ...
# 6570  270000000                             Superman Returns
# 14    280000000                      Avengers: Age of Ultron
# 7387  300000000     Pirates of the Caribbean: At World's End
# 3375  380000000  Pirates of the Caribbean: On Stranger Tides
# 2244  425000000                            The Warrior's Way
#
# [10865 rows x 2 columns]

# %%
sns.set()
_ = plt.hist(sortedList1["budget"],bins = 8)
_ = plt.xlabel("Budget")
_ = plt.ylabel("Number of Movies")
_ = plt.title("sortedList1")
_ = plt.show()

# %% [markdown]
# Dropping the null values in the dataset

# %%
sortedList1 = sortedList1[sortedList1.budget != 0]
sortedList1
# Out:
#          budget                               original_title
# 1151          1                                  Fear Clinic
# 3065          1           Angus, Thongs and Perfect Snogging
# 2618          1                                 Lost & Found
# 3581          1                      Love, Wedding, Marriage
# 8944          2                                 Death Wish 2
# ...         ...                                          ...
# 6570  270000000                             Superman Returns
# 14    280000000                      Avengers: Age of Ultron
# 7387  300000000     Pirates of the Caribbean: At World's End
# 3375  380000000  Pirates of the Caribbean: On Stranger Tides
# 2244  425000000                            The Warrior's Way
#
# [5169 rows x 2 columns]

# %%
sortedList1.iloc[2,:]
# Out:
# budget                       1
# original_title    Lost & Found
# Name: 2618, dtype: object

# %%
sortedList1.iloc[-3,:]
# Out:
# budget                                           300000000
# original_title    Pirates of the Caribbean: At World's End
# Name: 7387, dtype: object

# %% [markdown]
# Conclusion:
#            From the above dataframe it is observed that
#            1.Third lowest budget movie is Lost & Found.
#            2.Third highest budget movie is Pirates of the Caribbean: At World's End.

# %% [markdown]
# # 2.What is the average number of words in movie titles between the years 2000-2005?

# %%
#Feature Selection.
q2 = df[['release_year','original_title']]
q2
# Out:
#       release_year                               original_title
# 74            2015                       Mythica: The Darkspore
# 75            2015               Me and Earl and the Dying Girl
# 92            2015                     Mythica: The Necromancer
# 100           2015                                 Frozen Fever
# 101           2015                                    High-Rise
# ...            ...                                          ...
# 6570          2006                             Superman Returns
# 14            2015                      Avengers: Age of Ultron
# 7387          2007     Pirates of the Caribbean: At World's End
# 3375          2011  Pirates of the Caribbean: On Stranger Tides
# 2244          2010                            The Warrior's Way
#
# [10865 rows x 2 columns]

# %%
sortedList2 = q2.sort_values("release_year")

# %%
sortedList2
# Out:
#        release_year                     original_title
# 10154          1960  Saturday Night and Sunday Morning
# 10159          1960                      Midnight Lace
# 10161          1960                          The Alamo
# 10160          1960         The Little Shop of Horrors
# 10162          1960                 Sink the Bismarck!
# ...             ...                                ...
# 614            2015                 The Suicide Theory
# 613            2015                          King Jack
# 612            2015                         Dawg Fight
# 622            2015                 A Ballerina's Tale
# 74             2015             Mythica: The Darkspore
#
# [10865 rows x 2 columns]

# %%
_ = plt.hist(sortedList2["release_year"],bins = 5)
_ = plt.xlabel("Release Year")
_ = plt.ylabel("Number of Movies")
_ = plt.title("SortedList2")
_ = plt.show()

# %%
sortedList2.set_index("release_year")
# Out:
#                                  original_title
# release_year
# 1960          Saturday Night and Sunday Morning
# 1960                              Midnight Lace
# 1960                                  The Alamo
# 1960                 The Little Shop of Horrors
# 1960                         Sink the Bismarck!
# ...                                         ...
# 2015                         The Suicide Theory
# 2015                                  King Jack
# 2015                                 Dawg Fight
# 2015                         A Ballerina's Tale
# 2015                     Mythica: The Darkspore
#
# [10865 rows x 1 columns]

# %%
#Sorting movies in between the release year 2000 and 2005
newsortedList2 = sortedList2[(sortedList2["release_year"]>=2000) & (sortedList2["release_year"]<=2005)]

# %%
newsortedList2
# Out:
#       release_year                                     original_title
# 8736          2000                                           Scream 3
# 8820          2000  Shriek If You Know What I Did Last Friday the ...
# 8701          2000                            Dude, Whereâ€™s My Car?
# 8862          2000                              Shadow of the Vampire
# 8738          2000                                     Vertical Limit
# ...            ...                                                ...
# 6270          2005                                    Son of the Mask
# 6390          2005                                       The Best Man
# 6541          2005                                   Alien Apocalypse
# 6534          2005                 The Prize Winner of Defiance, Ohio
# 6466          2005                                     Bob the Butler
#
# [1687 rows x 2 columns]

# %%
newsortedList2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1687 entries, 8736 to 6466
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   release_year    1687 non-null   int64
#  1   original_title  1687 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 39.5+ KB

# %%
word = newsortedList2["original_title"].str.split().map(len)

# %%
word
# Out:
# 8736     2
# 8820    11
# 8701     4
# 8862     4
# 8738     2
#         ..
# 6270     4
# 6390     3
# 6541     2
# 6534     6
# 6466     3
# Name: original_title, Length: 1687, dtype: int64

# %%
words=word.mean()

# %%
words
# Out:
# 2.879668049792531

# %%
round(words)
# Out:
# 3

# %% [markdown]
# Conclusion: The average number of words in the movie titles between 2000-2005 is 3

# %% [markdown]
# # 4.Which are the movies with the most and least earned revenue?

# %%
#Feature Selection.
q4 = df[["revenue","original_title"]]

# %%
q4
# Out:
#          revenue                               original_title
# 74             0                       Mythica: The Darkspore
# 75             0               Me and Earl and the Dying Girl
# 92             0                     Mythica: The Necromancer
# 100            0                                 Frozen Fever
# 101            0                                    High-Rise
# ...          ...                                          ...
# 6570   391081192                             Superman Returns
# 14    1405035767                      Avengers: Age of Ultron
# 7387   961000000     Pirates of the Caribbean: At World's End
# 3375  1021683000  Pirates of the Caribbean: On Stranger Tides
# 2244    11087569                            The Warrior's Way
#
# [10865 rows x 2 columns]

# %%
sortedList4 = q4.sort_values("revenue")

# %%
sortedList4
# Out:
#          revenue                original_title
# 74             0        Mythica: The Darkspore
# 9386           0                    King Ralph
# 9385           0           Defending Your Life
# 9383           0             Suburban Commando
# 9377           0          Ernest Scared Stupid
# ...          ...                           ...
# 0     1513528810                Jurassic World
# 4361  1519557910                  The Avengers
# 5231  1845034188                       Titanic
# 3     2068178225  Star Wars: The Force Awakens
# 1386  2781505847                        Avatar
#
# [10865 rows x 2 columns]

# %%
ecdf(sortedList4["revenue"])
# Out:
# (array([         0,          0,          0, ..., 1845034188, 2068178225,
#         2781505847]),
#  array([9.20386562e-05, 1.84077312e-04, 2.76115969e-04, ...,
#         9.99815923e-01, 9.99907961e-01, 1.00000000e+00]))

# %%
x,y = ecdf(sortedList4["revenue"])

# %%
plt.plot(x,y)
plt.show()

# %%
min = sortedList4["revenue"].min()
min
# Out:
# 0

# %%
max = sortedList4["revenue"].max()
max
# Out:
# 2781505847

# %%
sortedList4[(sortedList4["revenue"] == min) | (sortedList4["revenue"] == max)]
# Out:
#          revenue           original_title
# 74             0   Mythica: The Darkspore
# 9386           0               King Ralph
# 9385           0      Defending Your Life
# 9383           0        Suburban Commando
# 9377           0     Ernest Scared Stupid
# ...          ...                      ...
# 3287           0                     Race
# 3903           0  Une bouteille Ã  la mer
# 3201           0           Lost in Austen
# 3199           0            Extreme Movie
# 1386  2781505847                   Avatar
#
# [6017 rows x 2 columns]

# %% [markdown]
# Conclusion :
#             The movies with the most and least earned revenue are:
#             1.Least earned : Extreme Movie
#             2.Most earned : Avatar

# %% [markdown]
# # 5.What is the average runtime of movies in the year 2006?

# %%
q5 = df[["release_year","runtime"]]

# %%
q5
# Out:
#       release_year  runtime
# 74            2015      108
# 75            2015      105
# 92            2015        0
# 100           2015        8
# 101           2015      119
# ...            ...      ...
# 6570          2006      154
# 14            2015      141
# 7387          2007      169
# 3375          2011      136
# 2244          2010      100
#
# [10865 rows x 2 columns]

# %%
sortedList5 = q5.sort_values("release_year")

# %%
sortedList5["release_year"]==2006
# Out:
# 10154    False
# 10159    False
# 10161    False
# 10160    False
# 10162    False
#          ...
# 614      False
# 613      False
# 612      False
# 622      False
# 74       False
# Name: release_year, Length: 10865, dtype: bool

# %%
df.groupby(sortedList5["release_year"]==2006).mean()['runtime']
# Out:
# release_year
# False    102.086927
# True     101.683824
# Name: runtime, dtype: float64

# %% [markdown]
# AVG runtime of movies in year 2006 = 101.683824

# %% [markdown]
#                                                OR

# %%
newsortedList5 = sortedList5[sortedList5["release_year"]==2006]

# %%
newsortedList5
# Out:
#       release_year  runtime
# 6648          2006      108
# 6649          2006      102
# 6635          2006       93
# 6737          2006       95
# 6722          2006      101
# ...            ...      ...
# 6837          2006       77
# 6856          2006       86
# 6646          2006       73
# 6706          2006      101
# 6840          2006       89
#
# [408 rows x 2 columns]

# %%
newsortedList5["runtime"].mean()
# Out:
# 101.68382352941177

# %%
ecdf(newsortedList5["runtime"])
# Out:
# (array([  0,   3,   5,   7,   7,   7,  11,  14,  23,  32,  41,  63,  69,
#          71,  72,  72,  73,  73,  73,  73,  74,  75,  75,  75,  75,  75,
#          76,  76,  77,  77,  78,  78,  79,  80,  80,  80,  81,  81,  82,
#          83,  83,  83,  83,  83,  83,  83,  84,  84,  84,  84,  84,  84,
#          85,  85,  85,  85,  85,  85,  85,  85,  85,  85,  86,  86,  86,
#          86,  86,  86,  87,  87,  87,  87,  87,  87,  87,  87,  87,  88,
#          88,  88,  88,  88,  88,  88,  88,  88,  88,  88,  88,  88,  89,
#          89,  89,  90,  90,  90,  90,  90,  90,  90,  90,  90,  90,  90,
#          90,  90,  90,  90,  90,  90,  90,  90,  90,  91,  91,  91,  91,
#          91,  91,  91,  91,  91,  91,  91,  91,  91,  91,  91,  91,  91,
#          92,  92,  92,  92,  92,  92,  92,  92,  92,  92,  92,  92,  92,
#          93,  93,  93,  93,  93,  93,  93,  93,  93,  93,  93,  93,  93,
#          93,  93,  93,  94,  94,  94,  94,  94,  94,  94,  94,  94,  95,
# ...

# %%
x ,y = ecdf(newsortedList5["runtime"])

# %%
_ = plt.plot(x,y)
_ = plt.xlabel("Runtime")
_ = plt.title("New Sorted List 5")
_ = plt.show()

# %% [markdown]
# Conclusion:
#            Average runtime of movies in the year 2006 is 101.68382352941177.
